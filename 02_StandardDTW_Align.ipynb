# %% [markdown]
# # Standard DTW Alignment

# %% [markdown]
# The goal of this notebook is to align files using standard DTW

# %%
# %matplotlib inline
# %load_ext Cython

# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa as lb
import os.path
from pathlib import Path
import pickle
import multiprocessing
import time
import gc
import seaborn as sns
import glob
import pandas as pd

# %% [markdown]
# ### Align with Standard DTW baseline

# %% [markdown]
# The following cell contains a cython implementation of basic DTW.

# %%
# %%cython
# import numpy as np
# cimport numpy as np
# cimport cython
#
# import sys
# import time
#
#
# DTYPE_INT32 = np.int32
# ctypedef np.int32_t DTYPE_INT32_t
#
# DTYPE_FLOAT = np.float64
# ctypedef np.float64_t DTYPE_FLOAT_t
#
# cdef DTYPE_FLOAT_t MAX_FLOAT = float('inf')
#
# # careful, without bounds checking can mess up memory - also can't use negative indices I think (like x[-1])
# @cython.boundscheck(False) # turn off bounds-checking for entire function
# def DTW_Cost_To_AccumCostAndSteps(Cin, parameter):
#     '''
#     Inputs
#         C: The cost Matrix
#     '''
#
#
#     '''
#     Section for checking and catching errors in the inputs
#     '''
#
#     cdef np.ndarray[DTYPE_FLOAT_t, ndim=2] C
#     try:
#         C = np.array(Cin, dtype=DTYPE_FLOAT)
#     except TypeError:
#         print(bcolors.FAIL + "FAILURE: The type of the cost matrix is wrong - please pass in a 2-d numpy array" + bcolors.ENDC)
#         return [-1, -1, -1]
#     except ValueError:
#         print(bcolors.FAIL + "FAILURE: The type of the elements in the cost matrix is wrong - please have each element be a float (perhaps you passed in a matrix of ints?)" + bcolors.ENDC)
#         return [-1, -1, -1]
#
#     cdef np.ndarray[np.uint32_t, ndim=1] dn
#     cdef np.ndarray[np.uint32_t, ndim=1] dm
#     cdef np.ndarray[DTYPE_FLOAT_t, ndim=1] dw
#     # make sure dn, dm, and dw are setup
#     # dn loading and exception handling
#     if ('dn'  in parameter.keys()):
#         try:
#
#             dn = np.array(parameter['dn'], dtype=np.uint32)
#         except TypeError:
#             print(bcolors.FAIL + "FAILURE: The type of dn (row steps) is wrong - please pass in a 1-d numpy array that holds uint32s" + bcolors.ENDC)
#             return [-1, -1, -1]
#         except ValueError:
#             print(bcolors.FAIL + "The type of the elements in dn (row steps) is wrong - please have each element be a uint32 (perhaps you passed a long?). You can specify this when making a numpy array like: np.array([1,2,3],dtype=np.uint32)" + bcolors.ENDC)
#             return [-1, -1, -1]
#     else:
#         dn = np.array([1, 1, 0], dtype=np.uint32)
#     # dm loading and exception handling
#     if 'dm'  in parameter.keys():
#         try:
#             dm = np.array(parameter['dm'], dtype=np.uint32)
#         except TypeError:
#             print(bcolors.FAIL + "FAILURE: The type of dm (col steps) is wrong - please pass in a 1-d numpy array that holds uint32s" + bcolors.ENDC)
#             return [-1, -1, -1]
#         except ValueError:
#             print(bcolors.FAIL + "FAILURE: The type of the elements in dm (col steps) is wrong - please have each element be a uint32 (perhaps you passed a long?). You can specify this when making a numpy array like: np.array([1,2,3],dtype=np.uint32)" + bcolors.ENDC)
#             return [-1, -1, -1]
#     else:
#         print(bcolors.FAIL + "dm (col steps) was not passed in (gave default value [1,0,1]) " + bcolors.ENDC)
#         dm = np.array([1, 0, 1], dtype=np.uint32)
#     # dw loading and exception handling
#     if 'dw'  in parameter.keys():
#         try:
#             dw = np.array(parameter['dw'], dtype=DTYPE_FLOAT)
#         except TypeError:
#             print(bcolors.FAIL + "FAILURE: The type of dw (step weights) is wrong - please pass in a 1-d numpy array that holds floats" + bcolors.ENDC)
#             return [-1, -1, -1]
#         except ValueError:
#             print(bcolors.FAIL + "FAILURE:The type of the elements in dw (step weights) is wrong - please have each element be a float (perhaps you passed ints or a long?). You can specify this when making a numpy array like: np.array([1,2,3],dtype=np.float64)" + bcolors.ENDC)
#             return [-1, -1, -1]
#     else:
#         dw = np.array([1, 1, 1], dtype=DTYPE_FLOAT)
#         print(bcolors.FAIL + "dw (step weights) was not passed in (gave default value [1,1,1]) " + bcolors.ENDC)
#
#
#     '''
#     Section where types are given to the variables we're going to use
#     '''
#     # create matrices to store our results (D and E)
#     cdef DTYPE_INT32_t numRows = C.shape[0] # only works with np arrays, use np.shape(x) will work on lists? want to force to use np though?
#     cdef DTYPE_INT32_t numCols = C.shape[1]
#     cdef DTYPE_INT32_t numDifSteps = np.size(dw)
#
#     cdef unsigned int maxRowStep = max(dn)
#     cdef unsigned int maxColStep = max(dm)
#
#     cdef np.ndarray[np.uint32_t, ndim=2] steps = np.zeros((numRows,numCols), dtype=np.uint32)
#     cdef np.ndarray[DTYPE_FLOAT_t, ndim=2] accumCost = np.ones((maxRowStep + numRows, maxColStep + numCols), dtype=DTYPE_FLOAT) * MAX_FLOAT
#
#     cdef DTYPE_FLOAT_t bestCost
#     cdef DTYPE_INT32_t bestCostIndex
#     cdef DTYPE_FLOAT_t costForStep
#     cdef unsigned int row, col
#     cdef unsigned int stepIndex
#
#     '''
#     The start of the actual algorithm, now that all our variables are set up
#     '''
#     # initializing the cost matrix - depends on whether its subsequence DTW
#     # essentially allow us to hop on the bottom anywhere (so could start partway through one of the signals)
#     if parameter['SubSequence']:
#         for col in range(numCols):
#             accumCost[maxRowStep, col + maxColStep] = C[0, col]
#     else:
#         accumCost[maxRowStep, maxColStep] = C[0,0]
#
#     # filling the accumulated cost matrix
#     for row in range(maxRowStep, numRows + maxRowStep, 1):
#         for col in range(maxColStep, numCols + maxColStep, 1):
#             bestCost = accumCost[<unsigned int>row, <unsigned int>col] # initialize with what's there - so if is an entry point, then can start low
#             bestCostIndex = 0
#             # go through each step, find the best one
#             for stepIndex in range(numDifSteps):
#                 #costForStep = accumCost[<unsigned int>(row - dn[<unsigned int>(stepIndex)]), <unsigned int>(col - dm[<unsigned int>(stepIndex)])] + dw[<unsigned int>(stepIndex)] * C[<unsigned int>(row - maxRowStep), <unsigned int>(col - maxColStep)]
#                 costForStep = accumCost[<unsigned int>((row - dn[(stepIndex)])), <unsigned int>((col - dm[(stepIndex)]))] + dw[stepIndex] * C[<unsigned int>(row - maxRowStep), <unsigned int>(col - maxColStep)]
#                 if costForStep < bestCost:
#                     bestCost = costForStep
#                     bestCostIndex = stepIndex
#             # save the best cost and best cost index
#             accumCost[row, col] = bestCost
#             steps[<unsigned int>(row - maxRowStep), <unsigned int>(col - maxColStep)] = bestCostIndex
#
#     # return the accumulated cost along with the matrix of steps taken to achieve that cost
#     return [accumCost[maxRowStep:, maxColStep:], steps]
#
# @cython.boundscheck(False) # turn off bounds-checking for entire function
# def DTW_GetPath(np.ndarray[DTYPE_FLOAT_t, ndim=2] accumCost, np.ndarray[np.uint32_t, ndim=2] stepsForCost, parameter):
#     '''
#
#     Parameter should have: 'dn', 'dm', 'dw', 'SubSequence'
#     '''
#
#     cdef np.ndarray[unsigned int, ndim=1] dn
#     cdef np.ndarray[unsigned int, ndim=1] dm
#     cdef np.uint8_t subseq
#     cdef np.int32_t startCol # added
#     # make sure dn, dm, and dw are setup
#     if ('dn'  in parameter.keys()):
#         dn = parameter['dn']
#     else:
#         dn = np.array([1, 1, 0], dtype=DTYPE_INT32)
#     if 'dm'  in parameter.keys():
#         dm = parameter['dm']
#     else:
#         dm = np.array([1, 0, 1], dtype=DTYPE_INT32)
#     if 'SubSequence' in parameter.keys():
#         subseq = parameter['SubSequence']
#     else:
#         subseq = 0
#
#     # added START
#     if 'startCol' in parameter.keys():
#         startCol = parameter['startCol']
#     else:
#         startCol = -1
#     # added END
#
#     cdef np.uint32_t numRows
#     cdef np.uint32_t numCols
#     cdef np.uint32_t curRow
#     cdef np.uint32_t curCol
#     cdef np.uint32_t endCol
#     cdef DTYPE_FLOAT_t endCost
#
#     numRows = accumCost.shape[0]
#     numCols = accumCost.shape[1]
#
#     # either start at the far corner (non sub-sequence)
#     # or start at the lowest cost entry in the last row (sub-sequence)
#     # where all of the signal along the row has been used, but only a
#     # sub-sequence of the signal along the columns has to be used
#     curRow = numRows - 1
#     if subseq:
#         curCol = np.argmin(accumCost[numRows - 1, :])
#     else:
#         curCol = numCols - 1
#
#     # added - if specified, overrides above
#     if startCol >= 0:
#         curCol = startCol
#
#     endCol = curCol
#     endCost = accumCost[curRow, curCol]
#
#     cdef np.uint32_t curRowStep
#     cdef np.uint32_t curColStep
#     cdef np.uint32_t curStepIndex
#
#
#     cdef np.ndarray[np.uint32_t, ndim=2] path = np.zeros((2, numRows + numCols), dtype=np.uint32) # make as large as could need, then chop at the end
#     path[0, 0] = curRow
#     path[1, 0] = curCol
#
#     cdef np.uint32_t stepsInPath = 1 # starts at one, we add in one before looping
#     cdef np.uint32_t stepIndex = 0
#     cdef np.int8_t done = (subseq and curRow == 0) or (curRow == 0 and curCol == 0)
#     while not done:
#         if accumCost[curRow, curCol] == MAX_FLOAT:
#             print('A path is not possible')
#             break
#
#         # you're done if you've made it to the bottom left (non sub-sequence)
#         # or just the bottom (sub-sequence)
#         # find the step size
#         curStepIndex = stepsForCost[curRow, curCol]
#         curRowStep = dn[curStepIndex]
#         curColStep = dm[curStepIndex]
#         # backtrack by 1 step
#         curRow = curRow - curRowStep
#         curCol = curCol - curColStep
#         # add your new location onto the path
#         path[0, stepsInPath] = curRow
#         path[1, stepsInPath] = curCol
#         stepsInPath = stepsInPath + 1
#         # check to see if you're done
#         done = (subseq and curRow == 0) or (curRow == 0 and curCol == 0)
#
#     # reverse the path (a matrix with two rows) and return it
#     return [np.fliplr(path[:, 0:stepsInPath]), endCol, endCost]
#
# class bcolors:
#     HEADER = '\033[95m'
#     OKBLUE = '\033[94m'
#     OKGREEN = '\033[92m'
#     WARNING = '\033[93m'
#     FAIL = '\033[91m'
#     ENDC = '\033[0m'
#     BOLD = '\033[1m'
#     UNDERLINE = '\033[4m'

# %%
def alignDTW(featfile1, featfile2, steps, weights, downsample, outfile = None, profile = False):
    
    F1 = np.load(featfile1) # 12 x N
    F2 = np.load(featfile2) # 12 x M
    if max(F1.shape[1], F2.shape[1]) / min(F1.shape[1], F2.shape[1]) >= 2: # no valid path possible
        if outfile:
            pickle.dump(None, open(outfile, 'wb'))
        return None
    times = []
    times.append(time.time())
    C = 1 - F1[:,0::downsample].T @ F2[:,0::downsample] # cos distance metric
    times.append(time.time())

    dn = steps[:,0].astype(np.uint32)
    dm = steps[:,1].astype(np.uint32)
    parameters = {'dn': dn, 'dm': dm, 'dw': weights, 'SubSequence': False}
    [D, s] = DTW_Cost_To_AccumCostAndSteps(C, parameters)
    times.append(time.time())
    [wp, endCol, endCost] = DTW_GetPath(D, s, parameters)
    times.append(time.time())
    if outfile:
        pickle.dump(wp, open(outfile, 'wb'))
    
    if profile:
        return wp, np.diff(times)
    else:
        return wp

# %%
def alignDTW_batch(querylist, featdir1, featdir2, outdir, n_cores, steps, weights, downsample):
    
    outdir.mkdir(parents=True, exist_ok=True)
    
    # prep inputs for parallelization
    inputs = []
    with open(querylist, 'r') as f:
        for line in f:
            parts = line.strip().split(' ')
            assert len(parts) == 2
            featfile1 = (featdir1 / parts[0]).with_suffix('.npy')
            featfile2 = (featdir2 / parts[1]).with_suffix('.npy')
            queryid = os.path.basename(parts[0]) + '__' + os.path.basename(parts[1])
            outfile = (outdir / queryid).with_suffix('.pkl')
            if os.path.exists(outfile):
                print(f"Skipping {outfile}")
            else:
                inputs.append((featfile1, featfile2, steps, weights, downsample, outfile))

    # process files in parallel
    pool = multiprocessing.Pool(processes = n_cores)
    pool.starmap(alignDTW, inputs)
    
    return

# %% [markdown]
# Align a single pair of audio files

# %%
featfile1 = 'features/clean/Chopin_Op068No3/Chopin_Op068No3_Tomsic-1995_pid9190-11.npy'
featfile2 = 'features/clean/Chopin_Op068No3/Chopin_Op068No3_Cortot-1951_pid9066b-19.npy'
steps = np.array([1,1,1,2,2,1]).reshape((-1,2))
weights = np.array([2,3,3])
downsample = 1
wp = alignDTW(featfile1, featfile2, steps, weights, downsample)

# %%
print(wp)
# Out:
# None

# %% [markdown]
# Align all pairs of audio files

# %%
query_list = 'cfg_files/query.test.list'
featdir1 = Path('features/clean')
featdir2 = Path('features/clean') # in case you want to align clean vs noisy
outdir = Path('experiments_test/dtw_clean')
n_cores = 1
steps = np.array([1,1,1,2,2,1]).reshape((-1,2))
weights = np.array([2,3,3])
downsample = 1
inputs = alignDTW_batch(query_list, featdir1, featdir2, outdir, n_cores, steps, weights, downsample)
# Out:
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Ax-1985_pid9179-07.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Bacha-1998_pid9166e-08.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Barbosa-1983_pid9174-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Ben-Or-1989_pid9161-13.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Biret-1990_pid9062-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Brailowsky-1960_pid9060-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Chiu-1999_pid9048-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Clidat-1994_pid9067-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Cohen-1997_pid9105-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Cortot-1951_pid9066-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Csalog-1996_pid1263-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Czerny-Stefanska-1989_pid9192-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Ezaki-2006_pid9139-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Falvay-1989_pid9068-10.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Fiorentino-1961_pid9065-10.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Fliere-1977_pid9063-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Fou-1978_pid9071-26.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Francois-1956_pid9070-23.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Goldenweiser-1946_pid917509-04.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Gornostaeva-1994_pid9116-06.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Groot-1988_pid9198g-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Hatto-1993_pid610003-17.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Hatto-2006_pid9073-17.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Horszowski-1983_pid9131-12.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Indjic-1988_pid9050-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Katin-1996_pid9126-03.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Kiepura-1999_pid9098-02.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Korecka-Soszkowska-1992_pid9128-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Kushner-1990_pid9118-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Lilamand-2001_pid9186c-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Luisada-1990_pid9055-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Luisada-2008_pid610242-01.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Lushtak-2004_pid9088-10.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Magaloff-1977_pid9074f-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Magin-1975_pid9138-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Malcuzynski-1951_pid9091-22.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Malcuzynski-1961_pid918904-03.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Meguri-1997_pid9137-09.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Milkina-1970_pid9099-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Mohovich-1999_pid9104-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Nezu-2005_pid9081-03.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Ohlsson-1999_pid9153-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Olejniczac-1990_pid9100b-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Osinska-1989_pid9101-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Perlemuter-1992_pid9089-08.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Poblocka-1999_pid9093-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Rangell-2001_pid9094-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Richter-1960_pid915410b-22.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Richter-1961_pid918722-04.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Rosen-1989_pid52932-08.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Rubinstein-1939_pid9049-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Rubinstein-1952_pid9075-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Rubinstein-1966_pid9059-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Rudanovskaya-2007_pid610242-02.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Shebanova-2002_pid9072-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Smith-1975_pid9054-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Sztompka-1959_pid9170-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Tanyel-1992_pid917813-03.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Tsujii-2005_pid9078-07.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Uninsky-1959_pid9061-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Vardi-1988_pid9173-20.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Wasowski-1980_pid9111-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ashkenazy-1981_pid9058-15__Chopin_Op024No2_Zimerman-1975_pid6100021-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Bacha-1998_pid9166e-08.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Barbosa-1983_pid9174-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Ben-Or-1989_pid9161-13.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Biret-1990_pid9062-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Brailowsky-1960_pid9060-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Chiu-1999_pid9048-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Clidat-1994_pid9067-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Cohen-1997_pid9105-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Cortot-1951_pid9066-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Csalog-1996_pid1263-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Czerny-Stefanska-1989_pid9192-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Ezaki-2006_pid9139-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Falvay-1989_pid9068-10.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Fiorentino-1961_pid9065-10.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Fliere-1977_pid9063-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Fou-1978_pid9071-26.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Francois-1956_pid9070-23.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Goldenweiser-1946_pid917509-04.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Gornostaeva-1994_pid9116-06.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Groot-1988_pid9198g-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Hatto-1993_pid610003-17.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Hatto-2006_pid9073-17.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Horszowski-1983_pid9131-12.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Indjic-1988_pid9050-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Katin-1996_pid9126-03.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Kiepura-1999_pid9098-02.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Korecka-Soszkowska-1992_pid9128-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Kushner-1990_pid9118-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Lilamand-2001_pid9186c-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Luisada-1990_pid9055-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Luisada-2008_pid610242-01.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Lushtak-2004_pid9088-10.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Magaloff-1977_pid9074f-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Magin-1975_pid9138-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Malcuzynski-1951_pid9091-22.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Malcuzynski-1961_pid918904-03.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Meguri-1997_pid9137-09.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Milkina-1970_pid9099-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Mohovich-1999_pid9104-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Nezu-2005_pid9081-03.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Ohlsson-1999_pid9153-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Olejniczac-1990_pid9100b-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Osinska-1989_pid9101-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Perlemuter-1992_pid9089-08.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Poblocka-1999_pid9093-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Rangell-2001_pid9094-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Richter-1960_pid915410b-22.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Richter-1961_pid918722-04.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Rosen-1989_pid52932-08.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Rubinstein-1939_pid9049-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Rubinstein-1952_pid9075-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Rubinstein-1966_pid9059-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Rudanovskaya-2007_pid610242-02.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Shebanova-2002_pid9072-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Smith-1975_pid9054-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Sztompka-1959_pid9170-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Tanyel-1992_pid917813-03.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Tsujii-2005_pid9078-07.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Uninsky-1959_pid9061-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Vardi-1988_pid9173-20.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Wasowski-1980_pid9111-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ax-1985_pid9179-07__Chopin_Op024No2_Zimerman-1975_pid6100021-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Barbosa-1983_pid9174-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Ben-Or-1989_pid9161-13.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Biret-1990_pid9062-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Brailowsky-1960_pid9060-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Chiu-1999_pid9048-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Clidat-1994_pid9067-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Cohen-1997_pid9105-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Cortot-1951_pid9066-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Csalog-1996_pid1263-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Czerny-Stefanska-1989_pid9192-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Ezaki-2006_pid9139-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Falvay-1989_pid9068-10.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Fiorentino-1961_pid9065-10.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Fliere-1977_pid9063-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Fou-1978_pid9071-26.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Francois-1956_pid9070-23.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Goldenweiser-1946_pid917509-04.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Gornostaeva-1994_pid9116-06.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Groot-1988_pid9198g-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Hatto-1993_pid610003-17.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Hatto-2006_pid9073-17.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Horszowski-1983_pid9131-12.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Indjic-1988_pid9050-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Katin-1996_pid9126-03.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Kiepura-1999_pid9098-02.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Korecka-Soszkowska-1992_pid9128-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Kushner-1990_pid9118-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Lilamand-2001_pid9186c-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Luisada-1990_pid9055-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Luisada-2008_pid610242-01.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Lushtak-2004_pid9088-10.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Magaloff-1977_pid9074f-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Magin-1975_pid9138-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Malcuzynski-1951_pid9091-22.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Malcuzynski-1961_pid918904-03.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Meguri-1997_pid9137-09.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Milkina-1970_pid9099-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Mohovich-1999_pid9104-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Nezu-2005_pid9081-03.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Ohlsson-1999_pid9153-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Olejniczac-1990_pid9100b-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Osinska-1989_pid9101-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Perlemuter-1992_pid9089-08.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Poblocka-1999_pid9093-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Rangell-2001_pid9094-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Richter-1960_pid915410b-22.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Richter-1961_pid918722-04.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Rosen-1989_pid52932-08.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Rubinstein-1939_pid9049-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Rubinstein-1952_pid9075-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Rubinstein-1966_pid9059-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Rudanovskaya-2007_pid610242-02.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Shebanova-2002_pid9072-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Smith-1975_pid9054-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Sztompka-1959_pid9170-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Tanyel-1992_pid917813-03.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Tsujii-2005_pid9078-07.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Uninsky-1959_pid9061-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Vardi-1988_pid9173-20.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Wasowski-1980_pid9111-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Bacha-1998_pid9166e-08__Chopin_Op024No2_Zimerman-1975_pid6100021-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Ben-Or-1989_pid9161-13.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Biret-1990_pid9062-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Brailowsky-1960_pid9060-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Chiu-1999_pid9048-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Clidat-1994_pid9067-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Cohen-1997_pid9105-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Cortot-1951_pid9066-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Csalog-1996_pid1263-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Czerny-Stefanska-1989_pid9192-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Ezaki-2006_pid9139-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Falvay-1989_pid9068-10.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Fiorentino-1961_pid9065-10.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Fliere-1977_pid9063-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Fou-1978_pid9071-26.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Francois-1956_pid9070-23.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Goldenweiser-1946_pid917509-04.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Gornostaeva-1994_pid9116-06.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Groot-1988_pid9198g-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Hatto-1993_pid610003-17.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Hatto-2006_pid9073-17.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Horszowski-1983_pid9131-12.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Indjic-1988_pid9050-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Katin-1996_pid9126-03.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Kiepura-1999_pid9098-02.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Korecka-Soszkowska-1992_pid9128-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Kushner-1990_pid9118-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Lilamand-2001_pid9186c-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Luisada-1990_pid9055-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Luisada-2008_pid610242-01.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Lushtak-2004_pid9088-10.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Magaloff-1977_pid9074f-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Magin-1975_pid9138-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Malcuzynski-1951_pid9091-22.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Malcuzynski-1961_pid918904-03.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Meguri-1997_pid9137-09.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Milkina-1970_pid9099-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Mohovich-1999_pid9104-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Nezu-2005_pid9081-03.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Ohlsson-1999_pid9153-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Olejniczac-1990_pid9100b-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Osinska-1989_pid9101-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Perlemuter-1992_pid9089-08.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Poblocka-1999_pid9093-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Rangell-2001_pid9094-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Richter-1960_pid915410b-22.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Richter-1961_pid918722-04.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Rosen-1989_pid52932-08.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Rubinstein-1939_pid9049-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Rubinstein-1952_pid9075-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Rubinstein-1966_pid9059-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Rudanovskaya-2007_pid610242-02.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Shebanova-2002_pid9072-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Smith-1975_pid9054-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Sztompka-1959_pid9170-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Tanyel-1992_pid917813-03.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Tsujii-2005_pid9078-07.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Uninsky-1959_pid9061-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Vardi-1988_pid9173-20.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Wasowski-1980_pid9111-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Barbosa-1983_pid9174-15__Chopin_Op024No2_Zimerman-1975_pid6100021-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Biret-1990_pid9062-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Brailowsky-1960_pid9060-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Chiu-1999_pid9048-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Clidat-1994_pid9067-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Cohen-1997_pid9105-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Cortot-1951_pid9066-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Csalog-1996_pid1263-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Czerny-Stefanska-1989_pid9192-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Ezaki-2006_pid9139-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Falvay-1989_pid9068-10.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Fiorentino-1961_pid9065-10.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Fliere-1977_pid9063-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Fou-1978_pid9071-26.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Francois-1956_pid9070-23.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Goldenweiser-1946_pid917509-04.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Gornostaeva-1994_pid9116-06.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Groot-1988_pid9198g-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Hatto-1993_pid610003-17.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Hatto-2006_pid9073-17.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Horszowski-1983_pid9131-12.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Indjic-1988_pid9050-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Katin-1996_pid9126-03.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Kiepura-1999_pid9098-02.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Korecka-Soszkowska-1992_pid9128-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Kushner-1990_pid9118-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Lilamand-2001_pid9186c-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Luisada-1990_pid9055-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Luisada-2008_pid610242-01.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Lushtak-2004_pid9088-10.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Magaloff-1977_pid9074f-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Magin-1975_pid9138-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Malcuzynski-1951_pid9091-22.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Malcuzynski-1961_pid918904-03.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Meguri-1997_pid9137-09.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Milkina-1970_pid9099-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Mohovich-1999_pid9104-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Nezu-2005_pid9081-03.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Ohlsson-1999_pid9153-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Olejniczac-1990_pid9100b-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Osinska-1989_pid9101-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Perlemuter-1992_pid9089-08.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Poblocka-1999_pid9093-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Rangell-2001_pid9094-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Richter-1960_pid915410b-22.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Richter-1961_pid918722-04.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Rosen-1989_pid52932-08.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Rubinstein-1939_pid9049-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Rubinstein-1952_pid9075-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Rubinstein-1966_pid9059-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Rudanovskaya-2007_pid610242-02.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Shebanova-2002_pid9072-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Smith-1975_pid9054-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Sztompka-1959_pid9170-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Tanyel-1992_pid917813-03.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Tsujii-2005_pid9078-07.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Uninsky-1959_pid9061-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Vardi-1988_pid9173-20.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Wasowski-1980_pid9111-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Ben-Or-1989_pid9161-13__Chopin_Op024No2_Zimerman-1975_pid6100021-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Brailowsky-1960_pid9060-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Chiu-1999_pid9048-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Clidat-1994_pid9067-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Cohen-1997_pid9105-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Cortot-1951_pid9066-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Csalog-1996_pid1263-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Czerny-Stefanska-1989_pid9192-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Ezaki-2006_pid9139-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Falvay-1989_pid9068-10.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Fiorentino-1961_pid9065-10.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Fliere-1977_pid9063-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Fou-1978_pid9071-26.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Francois-1956_pid9070-23.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Goldenweiser-1946_pid917509-04.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Gornostaeva-1994_pid9116-06.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Groot-1988_pid9198g-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Hatto-1993_pid610003-17.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Hatto-2006_pid9073-17.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Horszowski-1983_pid9131-12.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Indjic-1988_pid9050-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Katin-1996_pid9126-03.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Kiepura-1999_pid9098-02.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Korecka-Soszkowska-1992_pid9128-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Kushner-1990_pid9118-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Lilamand-2001_pid9186c-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Luisada-1990_pid9055-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Luisada-2008_pid610242-01.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Lushtak-2004_pid9088-10.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Magaloff-1977_pid9074f-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Magin-1975_pid9138-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Malcuzynski-1951_pid9091-22.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Malcuzynski-1961_pid918904-03.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Meguri-1997_pid9137-09.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Milkina-1970_pid9099-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Mohovich-1999_pid9104-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Nezu-2005_pid9081-03.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Ohlsson-1999_pid9153-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Olejniczac-1990_pid9100b-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Osinska-1989_pid9101-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Perlemuter-1992_pid9089-08.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Poblocka-1999_pid9093-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Rangell-2001_pid9094-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Richter-1960_pid915410b-22.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Richter-1961_pid918722-04.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Rosen-1989_pid52932-08.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Rubinstein-1939_pid9049-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Rubinstein-1952_pid9075-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Rubinstein-1966_pid9059-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Rudanovskaya-2007_pid610242-02.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Shebanova-2002_pid9072-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Smith-1975_pid9054-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Sztompka-1959_pid9170-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Tanyel-1992_pid917813-03.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Tsujii-2005_pid9078-07.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Uninsky-1959_pid9061-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Vardi-1988_pid9173-20.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Wasowski-1980_pid9111-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Biret-1990_pid9062-15__Chopin_Op024No2_Zimerman-1975_pid6100021-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Brailowsky-1960_pid9060-15__Chopin_Op024No2_Chiu-1999_pid9048-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Brailowsky-1960_pid9060-15__Chopin_Op024No2_Clidat-1994_pid9067-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Brailowsky-1960_pid9060-15__Chopin_Op024No2_Cohen-1997_pid9105-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Brailowsky-1960_pid9060-15__Chopin_Op024No2_Cortot-1951_pid9066-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Brailowsky-1960_pid9060-15__Chopin_Op024No2_Csalog-1996_pid1263-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Brailowsky-1960_pid9060-15__Chopin_Op024No2_Czerny-Stefanska-1989_pid9192-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Brailowsky-1960_pid9060-15__Chopin_Op024No2_Ezaki-2006_pid9139-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Brailowsky-1960_pid9060-15__Chopin_Op024No2_Falvay-1989_pid9068-10.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Brailowsky-1960_pid9060-15__Chopin_Op024No2_Fiorentino-1961_pid9065-10.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Brailowsky-1960_pid9060-15__Chopin_Op024No2_Fliere-1977_pid9063-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Brailowsky-1960_pid9060-15__Chopin_Op024No2_Fou-1978_pid9071-26.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Brailowsky-1960_pid9060-15__Chopin_Op024No2_Francois-1956_pid9070-23.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Brailowsky-1960_pid9060-15__Chopin_Op024No2_Goldenweiser-1946_pid917509-04.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Brailowsky-1960_pid9060-15__Chopin_Op024No2_Gornostaeva-1994_pid9116-06.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Brailowsky-1960_pid9060-15__Chopin_Op024No2_Groot-1988_pid9198g-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Brailowsky-1960_pid9060-15__Chopin_Op024No2_Hatto-1993_pid610003-17.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Brailowsky-1960_pid9060-15__Chopin_Op024No2_Hatto-2006_pid9073-17.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Brailowsky-1960_pid9060-15__Chopin_Op024No2_Horszowski-1983_pid9131-12.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Brailowsky-1960_pid9060-15__Chopin_Op024No2_Indjic-1988_pid9050-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Brailowsky-1960_pid9060-15__Chopin_Op024No2_Katin-1996_pid9126-03.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Brailowsky-1960_pid9060-15__Chopin_Op024No2_Kiepura-1999_pid9098-02.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Brailowsky-1960_pid9060-15__Chopin_Op024No2_Korecka-Soszkowska-1992_pid9128-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Brailowsky-1960_pid9060-15__Chopin_Op024No2_Kushner-1990_pid9118-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Brailowsky-1960_pid9060-15__Chopin_Op024No2_Lilamand-2001_pid9186c-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Brailowsky-1960_pid9060-15__Chopin_Op024No2_Luisada-1990_pid9055-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Brailowsky-1960_pid9060-15__Chopin_Op024No2_Luisada-2008_pid610242-01.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Brailowsky-1960_pid9060-15__Chopin_Op024No2_Lushtak-2004_pid9088-10.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Brailowsky-1960_pid9060-15__Chopin_Op024No2_Magaloff-1977_pid9074f-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Brailowsky-1960_pid9060-15__Chopin_Op024No2_Magin-1975_pid9138-15.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Brailowsky-1960_pid9060-15__Chopin_Op024No2_Malcuzynski-1951_pid9091-22.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Brailowsky-1960_pid9060-15__Chopin_Op024No2_Malcuzynski-1961_pid918904-03.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Brailowsky-1960_pid9060-15__Chopin_Op024No2_Meguri-1997_pid9137-09.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op024No2_Brailowsky-1960_pid9060-15__Chopin_Op024No2_Milkina-1970_pid9099-15.pkl
# ...
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Olejniczac-1990_pid9100b-08__Chopin_Op068No3_Smidowicz-1948_pid9091-17.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Olejniczac-1990_pid9100b-08__Chopin_Op068No3_Smith-1975_pid9054b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Olejniczac-1990_pid9100b-08__Chopin_Op068No3_Sofronitsky-1949_pid9114-34.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Olejniczac-1990_pid9100b-08__Chopin_Op068No3_Sztompka-1959_pid9170b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Olejniczac-1990_pid9100b-08__Chopin_Op068No3_Tomsic-1995_pid9190-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Olejniczac-1990_pid9100b-08__Chopin_Op068No3_Uninsky-1971_pid9061b-16.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Olejniczac-1990_pid9100b-08__Chopin_Op068No3_Wasowski-1980_pid9111b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Osinska-1989_pid9101c-15__Chopin_Op068No3_Rangell-2001_pid9094b-27.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Osinska-1989_pid9101c-15__Chopin_Op068No3_Richter-1976_pid9172-12.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Osinska-1989_pid9101c-15__Chopin_Op068No3_Rubinstein-1939_pid9049b-19.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Osinska-1989_pid9101c-15__Chopin_Op068No3_Rubinstein-1952_pid9075b-19.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Osinska-1989_pid9101c-15__Chopin_Op068No3_Rubinstein-1961_pid5667285b-10.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Osinska-1989_pid9101c-15__Chopin_Op068No3_Rubinstein-1966_pid9059b-23.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Osinska-1989_pid9101c-15__Chopin_Op068No3_Shebanova-2002_pid9072b-23.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Osinska-1989_pid9101c-15__Chopin_Op068No3_Smidowicz-1948_pid9082-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Osinska-1989_pid9101c-15__Chopin_Op068No3_Smidowicz-1948_pid9091-17.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Osinska-1989_pid9101c-15__Chopin_Op068No3_Smith-1975_pid9054b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Osinska-1989_pid9101c-15__Chopin_Op068No3_Sofronitsky-1949_pid9114-34.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Osinska-1989_pid9101c-15__Chopin_Op068No3_Sztompka-1959_pid9170b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Osinska-1989_pid9101c-15__Chopin_Op068No3_Tomsic-1995_pid9190-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Osinska-1989_pid9101c-15__Chopin_Op068No3_Uninsky-1971_pid9061b-16.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Osinska-1989_pid9101c-15__Chopin_Op068No3_Wasowski-1980_pid9111b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rangell-2001_pid9094b-27__Chopin_Op068No3_Richter-1976_pid9172-12.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rangell-2001_pid9094b-27__Chopin_Op068No3_Rubinstein-1939_pid9049b-19.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rangell-2001_pid9094b-27__Chopin_Op068No3_Rubinstein-1952_pid9075b-19.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rangell-2001_pid9094b-27__Chopin_Op068No3_Rubinstein-1961_pid5667285b-10.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rangell-2001_pid9094b-27__Chopin_Op068No3_Rubinstein-1966_pid9059b-23.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rangell-2001_pid9094b-27__Chopin_Op068No3_Shebanova-2002_pid9072b-23.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rangell-2001_pid9094b-27__Chopin_Op068No3_Smidowicz-1948_pid9082-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rangell-2001_pid9094b-27__Chopin_Op068No3_Smidowicz-1948_pid9091-17.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rangell-2001_pid9094b-27__Chopin_Op068No3_Smith-1975_pid9054b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rangell-2001_pid9094b-27__Chopin_Op068No3_Sofronitsky-1949_pid9114-34.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rangell-2001_pid9094b-27__Chopin_Op068No3_Sztompka-1959_pid9170b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rangell-2001_pid9094b-27__Chopin_Op068No3_Tomsic-1995_pid9190-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rangell-2001_pid9094b-27__Chopin_Op068No3_Uninsky-1971_pid9061b-16.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rangell-2001_pid9094b-27__Chopin_Op068No3_Wasowski-1980_pid9111b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Richter-1976_pid9172-12__Chopin_Op068No3_Rubinstein-1939_pid9049b-19.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Richter-1976_pid9172-12__Chopin_Op068No3_Rubinstein-1952_pid9075b-19.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Richter-1976_pid9172-12__Chopin_Op068No3_Rubinstein-1961_pid5667285b-10.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Richter-1976_pid9172-12__Chopin_Op068No3_Rubinstein-1966_pid9059b-23.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Richter-1976_pid9172-12__Chopin_Op068No3_Shebanova-2002_pid9072b-23.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Richter-1976_pid9172-12__Chopin_Op068No3_Smidowicz-1948_pid9082-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Richter-1976_pid9172-12__Chopin_Op068No3_Smidowicz-1948_pid9091-17.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Richter-1976_pid9172-12__Chopin_Op068No3_Smith-1975_pid9054b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Richter-1976_pid9172-12__Chopin_Op068No3_Sofronitsky-1949_pid9114-34.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Richter-1976_pid9172-12__Chopin_Op068No3_Sztompka-1959_pid9170b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Richter-1976_pid9172-12__Chopin_Op068No3_Tomsic-1995_pid9190-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Richter-1976_pid9172-12__Chopin_Op068No3_Uninsky-1971_pid9061b-16.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Richter-1976_pid9172-12__Chopin_Op068No3_Wasowski-1980_pid9111b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1939_pid9049b-19__Chopin_Op068No3_Rubinstein-1952_pid9075b-19.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1939_pid9049b-19__Chopin_Op068No3_Rubinstein-1961_pid5667285b-10.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1939_pid9049b-19__Chopin_Op068No3_Rubinstein-1966_pid9059b-23.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1939_pid9049b-19__Chopin_Op068No3_Shebanova-2002_pid9072b-23.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1939_pid9049b-19__Chopin_Op068No3_Smidowicz-1948_pid9082-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1939_pid9049b-19__Chopin_Op068No3_Smidowicz-1948_pid9091-17.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1939_pid9049b-19__Chopin_Op068No3_Smith-1975_pid9054b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1939_pid9049b-19__Chopin_Op068No3_Sofronitsky-1949_pid9114-34.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1939_pid9049b-19__Chopin_Op068No3_Sztompka-1959_pid9170b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1939_pid9049b-19__Chopin_Op068No3_Tomsic-1995_pid9190-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1939_pid9049b-19__Chopin_Op068No3_Uninsky-1971_pid9061b-16.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1939_pid9049b-19__Chopin_Op068No3_Wasowski-1980_pid9111b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1952_pid9075b-19__Chopin_Op068No3_Rubinstein-1961_pid5667285b-10.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1952_pid9075b-19__Chopin_Op068No3_Rubinstein-1966_pid9059b-23.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1952_pid9075b-19__Chopin_Op068No3_Shebanova-2002_pid9072b-23.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1952_pid9075b-19__Chopin_Op068No3_Smidowicz-1948_pid9082-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1952_pid9075b-19__Chopin_Op068No3_Smidowicz-1948_pid9091-17.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1952_pid9075b-19__Chopin_Op068No3_Smith-1975_pid9054b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1952_pid9075b-19__Chopin_Op068No3_Sofronitsky-1949_pid9114-34.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1952_pid9075b-19__Chopin_Op068No3_Sztompka-1959_pid9170b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1952_pid9075b-19__Chopin_Op068No3_Tomsic-1995_pid9190-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1952_pid9075b-19__Chopin_Op068No3_Uninsky-1971_pid9061b-16.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1952_pid9075b-19__Chopin_Op068No3_Wasowski-1980_pid9111b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1961_pid5667285b-10__Chopin_Op068No3_Rubinstein-1966_pid9059b-23.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1961_pid5667285b-10__Chopin_Op068No3_Shebanova-2002_pid9072b-23.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1961_pid5667285b-10__Chopin_Op068No3_Smidowicz-1948_pid9082-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1961_pid5667285b-10__Chopin_Op068No3_Smidowicz-1948_pid9091-17.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1961_pid5667285b-10__Chopin_Op068No3_Smith-1975_pid9054b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1961_pid5667285b-10__Chopin_Op068No3_Sofronitsky-1949_pid9114-34.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1961_pid5667285b-10__Chopin_Op068No3_Sztompka-1959_pid9170b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1961_pid5667285b-10__Chopin_Op068No3_Tomsic-1995_pid9190-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1961_pid5667285b-10__Chopin_Op068No3_Uninsky-1971_pid9061b-16.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1961_pid5667285b-10__Chopin_Op068No3_Wasowski-1980_pid9111b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1966_pid9059b-23__Chopin_Op068No3_Shebanova-2002_pid9072b-23.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1966_pid9059b-23__Chopin_Op068No3_Smidowicz-1948_pid9082-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1966_pid9059b-23__Chopin_Op068No3_Smidowicz-1948_pid9091-17.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1966_pid9059b-23__Chopin_Op068No3_Smith-1975_pid9054b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1966_pid9059b-23__Chopin_Op068No3_Sofronitsky-1949_pid9114-34.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1966_pid9059b-23__Chopin_Op068No3_Sztompka-1959_pid9170b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1966_pid9059b-23__Chopin_Op068No3_Tomsic-1995_pid9190-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1966_pid9059b-23__Chopin_Op068No3_Uninsky-1971_pid9061b-16.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Rubinstein-1966_pid9059b-23__Chopin_Op068No3_Wasowski-1980_pid9111b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Shebanova-2002_pid9072b-23__Chopin_Op068No3_Smidowicz-1948_pid9082-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Shebanova-2002_pid9072b-23__Chopin_Op068No3_Smidowicz-1948_pid9091-17.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Shebanova-2002_pid9072b-23__Chopin_Op068No3_Smith-1975_pid9054b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Shebanova-2002_pid9072b-23__Chopin_Op068No3_Sofronitsky-1949_pid9114-34.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Shebanova-2002_pid9072b-23__Chopin_Op068No3_Sztompka-1959_pid9170b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Shebanova-2002_pid9072b-23__Chopin_Op068No3_Tomsic-1995_pid9190-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Shebanova-2002_pid9072b-23__Chopin_Op068No3_Uninsky-1971_pid9061b-16.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Shebanova-2002_pid9072b-23__Chopin_Op068No3_Wasowski-1980_pid9111b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Smidowicz-1948_pid9082-11__Chopin_Op068No3_Smidowicz-1948_pid9091-17.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Smidowicz-1948_pid9082-11__Chopin_Op068No3_Smith-1975_pid9054b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Smidowicz-1948_pid9082-11__Chopin_Op068No3_Sofronitsky-1949_pid9114-34.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Smidowicz-1948_pid9082-11__Chopin_Op068No3_Sztompka-1959_pid9170b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Smidowicz-1948_pid9082-11__Chopin_Op068No3_Tomsic-1995_pid9190-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Smidowicz-1948_pid9082-11__Chopin_Op068No3_Uninsky-1971_pid9061b-16.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Smidowicz-1948_pid9082-11__Chopin_Op068No3_Wasowski-1980_pid9111b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Smidowicz-1948_pid9091-17__Chopin_Op068No3_Smith-1975_pid9054b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Smidowicz-1948_pid9091-17__Chopin_Op068No3_Sofronitsky-1949_pid9114-34.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Smidowicz-1948_pid9091-17__Chopin_Op068No3_Sztompka-1959_pid9170b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Smidowicz-1948_pid9091-17__Chopin_Op068No3_Tomsic-1995_pid9190-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Smidowicz-1948_pid9091-17__Chopin_Op068No3_Uninsky-1971_pid9061b-16.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Smidowicz-1948_pid9091-17__Chopin_Op068No3_Wasowski-1980_pid9111b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Smith-1975_pid9054b-21__Chopin_Op068No3_Sofronitsky-1949_pid9114-34.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Smith-1975_pid9054b-21__Chopin_Op068No3_Sztompka-1959_pid9170b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Smith-1975_pid9054b-21__Chopin_Op068No3_Tomsic-1995_pid9190-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Smith-1975_pid9054b-21__Chopin_Op068No3_Uninsky-1971_pid9061b-16.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Smith-1975_pid9054b-21__Chopin_Op068No3_Wasowski-1980_pid9111b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Sofronitsky-1949_pid9114-34__Chopin_Op068No3_Sztompka-1959_pid9170b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Sofronitsky-1949_pid9114-34__Chopin_Op068No3_Tomsic-1995_pid9190-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Sofronitsky-1949_pid9114-34__Chopin_Op068No3_Uninsky-1971_pid9061b-16.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Sofronitsky-1949_pid9114-34__Chopin_Op068No3_Wasowski-1980_pid9111b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Sztompka-1959_pid9170b-21__Chopin_Op068No3_Tomsic-1995_pid9190-11.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Sztompka-1959_pid9170b-21__Chopin_Op068No3_Uninsky-1971_pid9061b-16.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Sztompka-1959_pid9170b-21__Chopin_Op068No3_Wasowski-1980_pid9111b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Tomsic-1995_pid9190-11__Chopin_Op068No3_Uninsky-1971_pid9061b-16.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Tomsic-1995_pid9190-11__Chopin_Op068No3_Wasowski-1980_pid9111b-21.pkl
# Skipping experiments_test/dtw_clean/Chopin_Op068No3_Uninsky-1971_pid9061b-16__Chopin_Op068No3_Wasowski-1980_pid9111b-21.pkl
